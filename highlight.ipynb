# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole

m = Chem.MolFromSmiles('CC(C(C1=CC(=C(C=C1)O)O)O)N(C)C(=O)OCC2=CC=CC=C2')
substructure = Chem.MolFromSmarts('C(=O)O.c1ccccc1')
m.GetSubstructMatches(substructure)

m

# %%
from rdkit import Chem
m = Chem.MolFromSmiles('CC(C(C1=CC(=C(C=C1)O)O)O)N(C)C(=O)OCC2=CC=CC=C2')

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem import Recap,BRICS

fragmented=BRICS.BreakBRICSBonds(m)
pieces=Chem.GetMolFrags(fragmented,asMols=True)
Draw.MolsToGridImage(pieces)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x600 at 0x68BC148>

# %%
m2 = Chem.MolFromSmiles("CC(C(C1=CC(=C(C=C1)O)O)O)N(C)C(=O)OCC2=CC=CC=C2")
m2

fragmented=BRICS.BreakBRICSBonds(m2)
pieces=Chem.GetMolFrags(fragmented,asMols=True)
Draw.MolsToGridImage(pieces)

pieces[0]
